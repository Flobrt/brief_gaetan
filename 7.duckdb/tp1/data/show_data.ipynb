# %%
import pandas as pd

df = pd.read_csv('fact_resultats_epreuves.csv')

# %%
# Voirt toutes les colonnes de mon dataframe
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    id_resultat  id_resultat_source      source  id_athlete_base_resultats  \
# 0      6045706           600707072  infostrada                        NaN
# 1      6045707           600707073  infostrada                        NaN
# 2      6045708           600707074  infostrada                        NaN
# 3      6045709           600707075  infostrada                        NaN
# 4      6045710           600707076  infostrada                        NaN
#
#    id_personne athlete_nom athlete_prenom  id_equipe    equipe_en  id_pays  \
# 0          NaN         NaN            NaN        921        China       46
# 1          NaN         NaN            NaN        641        Japan      118
# 2          NaN         NaN            NaN        486  Switzerland      207
# 3          NaN         NaN            NaN     196999          ROC      387
# 4          NaN         NaN            NaN        408      Finland       74
#
# ...
